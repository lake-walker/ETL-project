# %%
# Dependecies 
# import dependencies and modules
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas as pd
import time
import requests
from pprint import pprint

# %%
# Import happiness data from csv
happy_2015 = pd.read_csv('data/happy_data/2015.csv')
happy_2016 = pd.read_csv('data/happy_data/2016.csv')
happy_2017 = pd.read_csv('data/happy_data/2017.csv')
happy_2018 = pd.read_csv('data/happy_data/2018.csv')
happy_2019 = pd.read_csv('data/happy_data/2019.csv')

# Rename country or regioin column into country 
happy_2015 = happy_2015.rename(columns={'Country': 'country'})
happy_2016 = happy_2016.rename(columns={'Country': 'country'})
happy_2016.dtypes
# Out:
# country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Import suicide data from csv
full_sui_data = pd.read_csv('data/suicide_data.csv')

# Create two new dataframes to hold the 2015 and 2016 data
sui_2015 = full_sui_data[full_sui_data['year'] == 2015]
sui_2016 =  full_sui_data[full_sui_data['year'] == 2016]

# Join the suicide data with the happiness data
sui_2016
# Out:
#         country  year     sex          age  suicides_no  population  \
# 1248    Armenia  2016    male    75+ years           12       61956
# 1249    Armenia  2016    male  55-74 years           16      237813
# 1250    Armenia  2016    male  35-54 years           16      350633
# 1251    Armenia  2016    male  15-24 years            5      202220
# 1252    Armenia  2016  female    75+ years            2      102414
# ...         ...   ...     ...          ...          ...         ...
# 25307  Thailand  2016  female    75+ years           69     1589015
# 25308  Thailand  2016  female  55-74 years          222     6049756
# 25309  Thailand  2016  female  35-54 years          375    10629684
# 25310  Thailand  2016  female  25-34 years          116     4702656
# 25311  Thailand  2016  female  15-24 years           60     4525574
#
#        suicides/100k pop  country-year  HDI for year  gdp_for_year ($)   \
# 1248               19.37   Armenia2016           NaN     10,546,135,160
# ...

# %%
happy_2016['year'] = 2016
happy_2016
happy_2015['year'] = 2015
happy_2016
# Out:
#          country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
# Join the the suicide data and happiness data
data_2015 = sui_2015.merge(happy_2015, on='country')
data_2016 = sui_2016.merge(happy_2016, on='country')

# %%
# for col in data_2016.columns:
#     print(col)
sui_2015
# Out:
#                    country  year     sex          age  suicides_no  \
# 576    Antigua and Barbuda  2015  female  55-74 years            1
# 577    Antigua and Barbuda  2015  female  15-24 years            0
# 578    Antigua and Barbuda  2015  female  25-34 years            0
# 579    Antigua and Barbuda  2015  female  35-54 years            0
# 580    Antigua and Barbuda  2015  female   5-14 years            0
# ...                    ...   ...     ...          ...          ...
# 27551              Uruguay  2015  female  25-34 years           23
# 27552              Uruguay  2015  female  35-54 years           38
# 27553              Uruguay  2015  female  15-24 years           17
# 27554              Uruguay  2015    male   5-14 years            3
# 27555              Uruguay  2015  female   5-14 years            2
#
#        population  suicides/100k pop  gdp_for_year ($)   gdp_per_capita ($)  \
# 576          6403              15.62      1,364,863,037               14853
# ...

# %%
# Drop useless columns
sui_2015 = sui_2015.drop(columns=['country-year','HDI for year'])
sui_2016 = sui_2016.drop(columns=['country-year','HDI for year'])

# %%
# Groupby country in order to gather data

# Concat the suicide data into one suicide dataframe
sui_data = pd.concat([sui_2015, sui_2016])
sui_data

# Concat the happiness data into one happiness dataframe
happy_data = pd.concat([happy_2015, happy_2016])

best_sui_data = sui_data.groupby('country').mean()
best_sui_data = best_sui_data.reset_index()
best_sui_data
# Out:
#                 country         year  suicides_no    population  \
# 0   Antigua and Barbuda  2015.000000     0.083333  7.657417e+03
# 1             Argentina  2015.000000   256.083333  3.308302e+06
# 2               Armenia  2015.454545     6.409091  2.361531e+05
# 3             Australia  2015.000000   252.250000  1.853399e+06
# 4               Austria  2015.454545   111.454545  7.138189e+05
# ..                  ...          ...          ...           ...
# 58         Turkmenistan  2015.000000    11.083333  4.072095e+05
# 59              Ukraine  2015.000000   631.166667  3.362120e+06
# 60       United Kingdom  2015.000000   409.166667  5.090245e+06
# 61        United States  2015.000000  3682.416667  2.500654e+07
# 62              Uruguay  2015.000000    52.500000  2.658996e+05
#
#     suicides/100k pop  gdp_per_capita ($)
# 0            1.301667        14853.000000
# 1            9.344167        14981.000000
# 2            3.901818         3780.909091
# ...

# %%
for col in data_2015.columns:
    print(col)
# Out:
# country
# year_x
# sex
# age
# suicides_no
# population
# suicides/100k pop
# country-year
# HDI for year
#  gdp_for_year ($)
# gdp_per_capita ($)
# generation
# Region
# Happiness Rank
# Happiness Score
# Standard Error
# Economy (GDP per Capita)
# Family
# Health (Life Expectancy)
# Freedom
# Trust (Government Corruption)
# Generosity
# Dystopia Residual
# year_y

# %%
# Concat the 2015 and the 2016 data
full_data = pd.concat([data_2015, data_2016])
full_data.dtypes
# Out:
# country                           object
# year_x                             int64
# sex                               object
# age                               object
# suicides_no                        int64
# population                         int64
# suicides/100k pop                float64
# country-year                      object
# HDI for year                     float64
#  gdp_for_year ($)                 object
# gdp_per_capita ($)                 int64
# generation                        object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# ...

# %%
# Create new dataframes in a relational format in order to move to SQL and a relational database
# Country id
country_df = full_data['country']
country_df = pd.DataFrame(country_df)
# Drop all the duplicates to get one piece of country data
clean_country = country_df.drop_duplicates()
# Generate ids for each country 
ids = np.random.randint(low=0, high=100, size = len(clean_country['country']))
clean_country['country_id'] = ids
clean_country.head()
# Out:
# C:\Users\lakew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#       country  country_id
# 0   Argentina          82
# 12    Armenia          72
# 24  Australia          16
# 36    Austria          90
# 48    Belgium          79

# %%
full_data
# Out:
#        country  year_x     sex          age  suicides_no  population  \
# 0    Argentina    2015    male    75+ years          245      712691
# 1    Argentina    2015    male  15-24 years          656     3500580
# 2    Argentina    2015    male  55-74 years          431     3011963
# 3    Argentina    2015    male  25-34 years          465     3289927
# 4    Argentina    2015    male  35-54 years          633     5166179
# ..         ...     ...     ...          ...          ...         ...
# 145   Thailand    2016  female    75+ years           69     1589015
# 146   Thailand    2016  female  55-74 years          222     6049756
# 147   Thailand    2016  female  35-54 years          375    10629684
# 148   Thailand    2016  female  25-34 years          116     4702656
# 149   Thailand    2016  female  15-24 years           60     4525574
#
#      suicides/100k pop   country-year  HDI for year  gdp_for_year ($)   ...  \
# ...

# %%
for col in full_data.columns:
    print(col)
# Out:
# country
# year_x
# sex
# age
# suicides_no
# population
# suicides/100k pop
# country-year
# HDI for year
#  gdp_for_year ($)
# gdp_per_capita ($)
# generation
# Region
# Happiness Rank
# Happiness Score
# Standard Error
# Economy (GDP per Capita)
# Family
# Health (Life Expectancy)
# Freedom
# Trust (Government Corruption)
# Generosity
# Dystopia Residual
# year_y
# Lower Confidence Interval
# Upper Confidence Interval

# %%
# Remove all the unnecessary columns from the full data set
cleaned_data = full_data.drop(columns=['year_y','Economy (GDP per Capita)','HDI for year','country-year'])

# %%
# Export full data file as csv to then be moved to MongoDB
cleaned_data.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\cleaned_data.csv', index=False, header=True)

# %%
# Create ids for year
year_df = full_data['year_x']
year_df = pd.DataFrame(year_df)
# Drop duplicates
clean_years = year_df.drop_duplicates()
# Generate ids
year_ids = np.random.randint(low=1000, high=9999, size = len(clean_years['year_x']))
clean_years['year_id'] = year_ids
clean_years = clean_years.rename(columns={'year_x':'year'})
clean_years
# Out:
# C:\Users\lakew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    year  year_id
# 0  2015     5114
# 0  2016     7670

# %%
# Create ids for sex
sex_df = full_data['sex']
sex_df = pd.DataFrame(sex_df)
# Drop duplicates
clean_sex = sex_df.drop_duplicates()
# Generate ids
sex_ids  = np.random.randint(low=1000, high=9999, size = len(clean_sex['sex']))
clean_sex['sex_id'] = sex_ids
clean_sex
# Out:
# C:\Users\lakew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       sex  sex_id
# 0    male    4243
# 5  female    6108

# %%
# Create ids for age
age_df = full_data['age']
age_df = pd.DataFrame(age_df)
# Drop duplicates
clean_age = age_df.drop_duplicates()
# Generate ids
age_ids  = np.random.randint(low=1000, high=9999, size = len(clean_age['age']))
clean_age['age_id'] = age_ids
clean_age
# Out:
# C:\Users\lakew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             age  age_id
# 0     75+ years    1758
# 1   15-24 years    9302
# 2   55-74 years    6848
# 3   25-34 years    3846
# 4   35-54 years    6356
# 10   5-14 years    6408

# %%
# Create ids for region
region_df = full_data['Region']
region_df = pd.DataFrame(region_df)
# Drop duplicates
clean_region = region_df.drop_duplicates()
# Generate ids
region_ids  = np.random.randint(low=9999, high=99000, size = len(clean_region['Region']))
clean_region['region_id'] = region_ids
clean_region
# Out:
# C:\Users\lakew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               Region  region_id
# 0        Latin America and Caribbean      84894
# 12        Central and Eastern Europe      23217
# 24         Australia and New Zealand      80230
# 36                    Western Europe      69941
# 252  Middle East and Northern Africa      74897
# 276                     Eastern Asia      50656
# 360               Sub-Saharan Africa      71510
# 480                Southeastern Asia      75892
# 612                    North America      69346

# %%
# Create ids for region
generation_df = full_data['generation']
generation_df = pd.DataFrame(generation_df)
# Drop duplicates
clean_generation = generation_df.drop_duplicates()
# Generate ids
generation_ids  = np.random.randint(low=9999, high=99000, size = len(clean_generation['generation']))
clean_generation['generation_id'] = generation_ids
clean_generation
# Out:
# C:\Users\lakew\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       generation  generation_id
# 0         Silent          63509
# 1     Millenials          64805
# 2        Boomers          91446
# 4   Generation X          73358
# 10  Generation Z          57188

# %%
# Add in the newly generated keys
# Start with country ids
new_sui_data = pd.merge(sui_data, clean_country, on='country')

# Add in year ids
# new_sui_data = pd.merge(new_sui_data, clean_years, on='year')

# Add in sex ids
new_sui_data = pd.merge(new_sui_data, clean_sex, on='sex')

# Add in age ids
new_sui_data = pd.merge(new_sui_data, clean_age, on='age')

# Add in region ids - no regions in s
# new_sui_data = pd.merge(new_sui_data, clean_region, on='Region')

# Add in generation ids
new_sui_data = pd.merge(new_sui_data, clean_generation, on='generation')
new_sui_data
# Out:
#             country  year     sex         age  suicides_no  population  \
# 0         Argentina  2015    male   75+ years          245      712691
# 1           Armenia  2015    male   75+ years           12       61355
# 2           Armenia  2016    male   75+ years           12       61956
# 3         Australia  2015    male   75+ years          181      673787
# 4           Austria  2015    male   75+ years          214      290329
# ..              ...   ...     ...         ...          ...         ...
# 781    Turkmenistan  2015  female  5-14 years            0      501611
# 782         Ukraine  2015  female  5-14 years           19     2010824
# 783  United Kingdom  2015  female  5-14 years            6     3663221
# 784   United States  2015  female  5-14 years          158    20342901
# 785         Uruguay  2015  female  5-14 years            2      241598
#
#      suicides/100k pop   gdp_for_year ($)   gdp_per_capita ($)    generation  \
# ...

# %%
# Add in the newly generated keys
# Start with country ids
new_happy_data = pd.merge(happy_data, clean_country, on='country')

# Add in year ids
# new_happy_data = pd.merge(new_happy_data, clean_years, on='year')

# Add in sex ids
# new_happy_data = pd.merge(new_happy_data, clean_sex, on='sex')

# Add in age ids
# new_sui_data = pd.merge(new_sui_data, clean_age, on='age')

# Add in region ids - no regions in s
new_happy_data = pd.merge(new_happy_data, clean_region, on='Region')

# Add in generation ids
# new_sui_data = pd.merge(new_sui_data, clean_generation, on='generation')
new_happy_data
# Out:
#           country              Region  Happiness Rank  Happiness Score  \
# 0     Switzerland      Western Europe               1            7.587
# 1     Switzerland      Western Europe               2            7.509
# 2         Iceland      Western Europe               2            7.561
# 3         Iceland      Western Europe               3            7.501
# 4         Denmark      Western Europe               3            7.527
# ..            ...                 ...             ...              ...
# 103      Mongolia        Eastern Asia             101            4.907
# 104     Mauritius  Sub-Saharan Africa              71            5.477
# 105     Mauritius  Sub-Saharan Africa              66            5.648
# 106  South Africa  Sub-Saharan Africa             113            4.642
# 107  South Africa  Sub-Saharan Africa             116            4.459
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
# Drop the original columns containing the data
clean_happy_data = new_happy_data.drop(['country','Region'], axis=1)
clean_sui_data = new_sui_data.drop(['country','sex','age','generation'], axis=1)
clean_happy_data.dtypes
# Out:
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# year                               int64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# country_id                         int32
# region_id                          int32
# dtype: object

# %%
# Export all the dataframes as csv files to be used in postgress
clean_country.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\country.csv', index=False, header=True)
# clean_years.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\years.csv', index=False, header=True)
clean_sex.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\sex.csv', index=False, header=True)
clean_age.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\age.csv', index=False, header=True)
clean_region.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\region.csv', index=False, header=True)
clean_generation.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\generation.csv', index=False, header=True)

clean_happy_data.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\happiness.csv', index=False, header=True)
clean_sui_data.to_csv(r'C:\Users\lakew\Documents\DuCamp\ETL-project\Clean_data\suicide.csv', index=False, header=True)
